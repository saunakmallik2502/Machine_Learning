# %% [markdown]
# # Project: Lending Club case study
# ### by Saunak Mallik - ML-C64 [Module: Statistics]

# %% [markdown]
# # 🪧🧱 Section 1: Data Understanding 🧱

# %%
# import essential libraries

# Numerical and Data analysis
import numpy as np
import pandas as pd

# Data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Extra - To suppress warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# import dataset
df = pd.read_csv('loan.csv')

# %% [markdown]
# ### 📋 Data exploration

# %%
# dataset has 39,717 rows (loan applicants' data) and 111 columns (attributes)
df.shape
# Out:
# (39717, 111)

# %%
# attribute names of dataset
df.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade',
#        ...
#        'num_tl_90g_dpd_24m', 'num_tl_op_past_12m', 'pct_tl_nvr_dlq',
#        'percent_bc_gt_75', 'pub_rec_bankruptcies', 'tax_liens',
#        'tot_hi_cred_lim', 'total_bal_ex_mort', 'total_bc_limit',
#        'total_il_high_credit_limit'],
#       dtype='object', length=111)

# %%
# df.info

# %%
# data exploration
df.head()
# Out:
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
#
#   int_rate  installment grade sub_grade  ... num_tl_90g_dpd_24m  \
# 0   10.65%       162.87     B        B2  ...                NaN
# 1   15.27%        59.83     C        C4  ...                NaN
# 2   15.96%        84.33     C        C5  ...                NaN
# 3   13.49%       339.31     C        C1  ...                NaN
# 4   12.69%        67.79     B        B5  ...                NaN
#
#   num_tl_op_past_12m pct_tl_nvr_dlq  percent_bc_gt_75 pub_rec_bankruptcies  \
# ...

# %%
# df.tail()

# %%
# summary statistics of data
df.describe()
# Out:
#                  id     member_id     loan_amnt   funded_amnt  \
# count  3.971700e+04  3.971700e+04  39717.000000  39717.000000
# mean   6.831319e+05  8.504636e+05  11219.443815  10947.713196
# std    2.106941e+05  2.656783e+05   7456.670694   7187.238670
# min    5.473400e+04  7.069900e+04    500.000000    500.000000
# 25%    5.162210e+05  6.667800e+05   5500.000000   5400.000000
# 50%    6.656650e+05  8.508120e+05  10000.000000   9600.000000
# 75%    8.377550e+05  1.047339e+06  15000.000000  15000.000000
# max    1.077501e+06  1.314167e+06  35000.000000  35000.000000
#
#        funded_amnt_inv   installment    annual_inc           dti  \
# count     39717.000000  39717.000000  3.971700e+04  39717.000000
# mean      10397.448868    324.561922  6.896893e+04     13.315130
# std        7128.450439    208.874874  6.379377e+04      6.678594
# min           0.000000     15.690000  4.000000e+03      0.000000
# 25%        5000.000000    167.020000  4.040400e+04      8.170000
# ...

# %% [markdown]
# # 🪧🧱 Section 2: Data Cleansing and Manipulation 🧱

# %% [markdown]
# ##  📋🛑Missing value checks
# #### Assumptions while taking care of missing values:
# - __Any column__ having __high %  (generally >40%) of missing values__ ideally ___should not be considered the part of analysis___, even if it is very relevent column. That's because, the insights coming out from that column might not be reliable.
#
# - Note: Alternatively, we could have used dropna to drop all columns with 100% Null values in one go, but that would have
# added one more stage on analysis to remove the 40% - 99% Null values.
#         - df = df.dropna(axis=1, how='all') #drop the all the columns which contans only NA

# %%
# Check for missing values based on mean > 40% Null values

# Calculate the percentage of NULL values in each column
df_isnull = 100 * df.isnull().mean()

# Calculate the columns wirh percentage of NULL values > 40% in each column
df_isnull_gt_40 = df_isnull[df_isnull>40]
df_isnull_gt_40
# Out:
# mths_since_last_delinq             64.662487
# mths_since_last_record             92.985372
# next_pymnt_d                       97.129693
# mths_since_last_major_derog       100.000000
# annual_inc_joint                  100.000000
# dti_joint                         100.000000
# verification_status_joint         100.000000
# tot_coll_amt                      100.000000
# tot_cur_bal                       100.000000
# open_acc_6m                       100.000000
# open_il_6m                        100.000000
# open_il_12m                       100.000000
# open_il_24m                       100.000000
# mths_since_rcnt_il                100.000000
# total_bal_il                      100.000000
# il_util                           100.000000
# open_rv_12m                       100.000000
# open_rv_24m                       100.000000
# max_bal_bc                        100.000000
# all_util                          100.000000
# total_rev_hi_lim                  100.000000
# ...

# %%
# Identify columns with more than 40% NULL values so that this can be used for imputation 
columns_with_nulls = df_isnull_gt_40.index

# Print the columns
print("Columns with more than 40% NULL values:")
print(columns_with_nulls)
# Out:
# Columns with more than 40% NULL values:
# Index(['mths_since_last_delinq', 'mths_since_last_record', 'next_pymnt_d',
#        'mths_since_last_major_derog', 'annual_inc_joint', 'dti_joint',
#        'verification_status_joint', 'tot_coll_amt', 'tot_cur_bal',
#        'open_acc_6m', 'open_il_6m', 'open_il_12m', 'open_il_24m',
#        'mths_since_rcnt_il', 'total_bal_il', 'il_util', 'open_rv_12m',
#        'open_rv_24m', 'max_bal_bc', 'all_util', 'total_rev_hi_lim', 'inq_fi',
#        'total_cu_tl', 'inq_last_12m', 'acc_open_past_24mths', 'avg_cur_bal',
#        'bc_open_to_buy', 'bc_util', 'mo_sin_old_il_acct',
#        'mo_sin_old_rev_tl_op', 'mo_sin_rcnt_rev_tl_op', 'mo_sin_rcnt_tl',
#        'mort_acc', 'mths_since_recent_bc', 'mths_since_recent_bc_dlq',
#        'mths_since_recent_inq', 'mths_since_recent_revol_delinq',
#        'num_accts_ever_120_pd', 'num_actv_bc_tl', 'num_actv_rev_tl',
#        'num_bc_sats', 'num_bc_tl', 'num_il_tl', 'num_op_rev_tl',
# ...

# %% [markdown]
# ##  📋🛑Imputation of missing values
# - Any column having high %  (generally >40%) of missing values ideally should not be considered the part of analysis
# even if it is very relevent column for use bcoz the insights coming out from that column might not be reliable.

# %%
df.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade',
#        ...
#        'num_tl_90g_dpd_24m', 'num_tl_op_past_12m', 'pct_tl_nvr_dlq',
#        'percent_bc_gt_75', 'pub_rec_bankruptcies', 'tax_liens',
#        'tot_hi_cred_lim', 'total_bal_ex_mort', 'total_bc_limit',
#        'total_il_high_credit_limit'],
#       dtype='object', length=111)

# %%
len(df.columns)
# Out:
# 111

# %% [markdown]
# ####  🛑 Drop the columns with > 40% missing values from the dataframe in one go

# %%
# drop the columns with > 40% missing values from the dataframe in one go
df.drop(columns=columns_with_nulls, axis=1, inplace=True)

# %%
df.shape # 54 columns after dropping the >40% null columns
# Out:
# (39717, 54)

# %%
df.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade', 'emp_title',
#        'emp_length', 'home_ownership', 'annual_inc', 'verification_status',
#        'issue_d', 'loan_status', 'pymnt_plan', 'url', 'desc', 'purpose',
#        'title', 'zip_code', 'addr_state', 'dti', 'delinq_2yrs',
#        'earliest_cr_line', 'inq_last_6mths', 'open_acc', 'pub_rec',
#        'revol_bal', 'revol_util', 'total_acc', 'initial_list_status',
#        'out_prncp', 'out_prncp_inv', 'total_pymnt', 'total_pymnt_inv',
#        'total_rec_prncp', 'total_rec_int', 'total_rec_late_fee', 'recoveries',
#        'collection_recovery_fee', 'last_pymnt_d', 'last_pymnt_amnt',
#        'last_credit_pull_d', 'collections_12_mths_ex_med', 'policy_code',
#        'application_type', 'acc_now_delinq', 'chargeoff_within_12_mths',
#        'delinq_amnt', 'pub_rec_bankruptcies', 'tax_liens'],
#       dtype='object')

# %% [markdown]
# ### 📋 Explore remaining columns for possible imputations

# %%
# Explore the remaining columns which contains at least some null values
# df.isnull().sum() # Display the remaining rows
df1  = 100*df.isnull().mean()
# df1.sort_values(ascending=False)
df1[df1>0]
# Out:
# emp_title                      6.191303
# emp_length                     2.706650
# desc                          32.580507
# title                          0.027696
# revol_util                     0.125891
# last_pymnt_d                   0.178765
# last_credit_pull_d             0.005036
# collections_12_mths_ex_med     0.140998
# chargeoff_within_12_mths       0.140998
# pub_rec_bankruptcies           1.754916
# tax_liens                      0.098195
# dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Data columns (total 54 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          39717 non-null  int64
#  1   member_id                   39717 non-null  int64
#  2   loan_amnt                   39717 non-null  int64
#  3   funded_amnt                 39717 non-null  int64
#  4   funded_amnt_inv             39717 non-null  float64
#  5   term                        39717 non-null  object
#  6   int_rate                    39717 non-null  object
#  7   installment                 39717 non-null  float64
#  8   grade                       39717 non-null  object
#  9   sub_grade                   39717 non-null  object
#  10  emp_title                   37258 non-null  object
#  11  emp_length                  38642 non-null  object
#  12  home_ownership              39717 non-null  object
# ...

# %% [markdown]
# ## 📋 🛑 Data cleansing/ Manipulation approach on each of the individual columns

# %%
'''
 ####   Column                      Non-Null Count  Dtype    Null %
---  ------                      --------------  -----  --------
 10  emp_title                   37258 non-null  object   6.191303 -- No Action
 11  emp_length                  38642 non-null  object   2.706650 -- to be evaluated further: remove, +, <, years
 19  desc                        26777 non-null  object  32.580507 -- No Action
 21  title                       39706 non-null  object   0.027696 -- No Action
 31  revol_util                  39667 non-null  object   0.125891 -- to be evaluated further: remove %
 43  last_pymnt_d                39646 non-null  object   0.178765 -- to be evaluated further: convert to date format
 45  last_credit_pull_d          39715 non-null  object   0.005036 -- to be evaluated further: convert to date format
 46  collections_12_mths_ex_med  39661 non-null  float64  0.140998 -- No Action; contains only 0.0
 50  chargeoff_within_12_mths    39661 non-null  float64  0.140998 -- No Action; contains only 0.0
 52  pub_rec_bankruptcies        39020 non-null  float64  1.754916 -- No Action; check if notna to be used
 53  tax_liens                   39678 non-null  float64  0.098195 -- No Action; contains only 0.0
'''
# Out:
# '\n ####   Column                      Non-Null Count  Dtype    Null %\n---  ------                      --------------  -----  --------\n 10  emp_title                   37258 non-null  object   6.191303 -- No Action\n 11  emp_length                  38642 non-null  object   2.706650 -- to be evaluated further: remove, +, <, years\n 19  desc                        26777 non-null  object  32.580507 -- No Action\n 21  title                       39706 non-null  object   0.027696 -- No Action\n 31  revol_util                  39667 non-null  object   0.125891 -- to be evaluated further: remove %\n 43  last_pymnt_d                39646 non-null  object   0.178765 -- to be evaluated further: convert to date format\n 45  last_credit_pull_d          39715 non-null  object   0.005036 -- to be evaluated further: convert to date format\n 46  collections_12_mths_ex_med  39661 non-null  float64  0.140998 -- No Action; contains only 0.0\n 50  chargeoff_within_12_mths    39661 non-null  float64  
# ...

# %%
# df['emp_title'].value_counts() - 
# df['emp_length'].value_counts() # to be evaluated
# df['desc'].value_counts() - 
# df['title'].value_counts()
# df['revol_util'].value_counts() # to be evaluated: remove %
# df['last_pymnt_d'].value_counts() # convert to date format
# df['last_credit_pull_d'].value_counts() # convert to date format
# df['collections_12_mths_ex_med'].value_counts() -- NA; column can be dropped as single value=0.0
# df['chargeoff_within_12_mths'].value_counts() -- NA; column can be dropped as single value=0.0
# df['pub_rec_bankruptcies'].value_counts()
# df['tax_liens'].value_counts() -- NA; column can be dropped as single value=0.0

# %% [markdown]
# #### column: emp_title (Imputation strategy):
# - 1. Replace rows of emp_title having null values with 'NA' ✅
# - 2. Remove rows having emp_title = NULL ❌ OR
# - 3. Replace rows of emp_title having null values with the MODE(emp_title) - doesn't see appropriate ❌
# - __FINAL decision is not to impute__ as this might skew the distribution (given that the largest single category is only 134 records).

# %%
df['emp_title'].value_counts()
# Out:
# US Army                      134
# Bank of America              109
# IBM                           66
# AT&T                          59
# Kaiser Permanente             56
#                             ...
# Altura Credit Union            1
# Fieldglass Inc                 1
# Hyundai AMCO America, Inc      1
# marvin & palmer assoc          1
# Paul Tally DDS                 1
# Name: emp_title, Length: 28820, dtype: int64

# %%
# excluding rows with Null values (String Data)
# df['emp_title']=df['emp_title'].fillna(df['emp_title'].mod())
# df1 = df [ df["emp_title"].notna() ]

# %% [markdown]
# #### column: emp_length (Imputation strategy):
# - 1. Remove +, < and years
# - 2. Replace rows having null values of emp_length with the MEDIAN(emp_length)

# %%
df['emp_length'].value_counts()
# Out:
# 10+ years    8879
# < 1 year     4583
# 2 years      4388
# 3 years      4095
# 4 years      3436
# 5 years      3282
# 1 year       3240
# 6 years      2229
# 7 years      1773
# 8 years      1479
# 9 years      1258
# Name: emp_length, dtype: int64

# %%
# remove, +, <, years & convery datatype to float
# Saunak: Using a nested function directly instead of using lambda function
df['emp_length'] = df['emp_length'].str.replace('years', '').str.replace('year', '').str.replace('<', '').str.replace('+', '').str.strip().astype('float')

# %%
'''
# remove, +, <, years & convery datatype to float
df['emp_length'] = df['emp_length'].str.strip('years') # .replace('<', '').replace('+', '').str.strip() # .astype('float')
df['emp_length'] = df['emp_length'].str.replace('+', '')
df['emp_length'] = df['emp_length'].str.replace('<', '')
df['emp_length'] = df['emp_length'].str.strip()
df['emp_length'] = df['emp_length'].astype('float')
df['emp_length'].value_counts()
'''
# Out:
# "\n# remove, +, <, years & convery datatype to float\ndf['emp_length'] = df['emp_length'].str.strip('years') # .replace('<', '').replace('+', '').str.strip() # .astype('float')\ndf['emp_length'] = df['emp_length'].str.replace('+', '')\ndf['emp_length'] = df['emp_length'].str.replace('<', '')\ndf['emp_length'] = df['emp_length'].str.strip()\ndf['emp_length'] = df['emp_length'].astype('float')\ndf['emp_length'].value_counts()\n"

# %%
# fill null values with median
df['emp_length'] = df['emp_length'].fillna(df['emp_length'].median())
df['emp_length']
# Out:
# 0        10.0
# 1         1.0
# 2        10.0
# 3        10.0
# 4         1.0
#          ...
# 39712     4.0
# 39713     3.0
# 39714     1.0
# 39715     1.0
# 39716     1.0
# Name: emp_length, Length: 39717, dtype: float64

# %%
df1  = 100*df.isnull().mean()
df1[df1>0]
# Out:
# emp_title                      6.191303
# desc                          32.580507
# title                          0.027696
# revol_util                     0.125891
# last_pymnt_d                   0.178765
# last_credit_pull_d             0.005036
# collections_12_mths_ex_med     0.140998
# chargeoff_within_12_mths       0.140998
# pub_rec_bankruptcies           1.754916
# tax_liens                      0.098195
# dtype: float64

# %% [markdown]
# #### column: revol_util (Imputation strategy):
# - 1. Remove %
# - 2. Replace rows having null values of emp_length with the MEDIAN(revol_util)

# %%
df['revol_util'].value_counts()
# Out:
# 0%        977
# 0.20%      63
# 63%        62
# 40.70%     58
# 66.70%     58
#          ...
# 18.82%      1
# 33.29%      1
# 5.33%       1
# 49.63%      1
# 25.33%      1
# Name: revol_util, Length: 1089, dtype: int64

# %%
# 1. remove % and convert to float
df['revol_util'] = df['revol_util'].str.rstrip('%').astype('float')
# df['revol_util'] = df['revol_util'].astype('float')

# %%
# 2. Replace rows having null values of emp_length with the MEDIAN(revol_util)
df['revol_util'] = df['revol_util'].fillna(df['revol_util'].median())
df['revol_util'].value_counts()
# Out:
# 0.00     977
# 49.30     93
# 0.20      63
# 63.00     62
# 66.70     58
#         ...
# 70.94      1
# 8.49       1
# 77.63      1
# 10.17      1
# 24.66      1
# Name: revol_util, Length: 1089, dtype: int64

# %% [markdown]
# #### column: last_pymnt_d (Imputation strategy):
# - 1. Convert last_pymnt_d to date format

# %%
df['last_pymnt_d'].value_counts()
# Out:
# May-16    1256
# Mar-13    1026
# Dec-14     945
# May-13     907
# Feb-13     869
#           ...
# Jun-08      10
# Nov-08      10
# Mar-08       5
# Jan-08       4
# Feb-08       1
# Name: last_pymnt_d, Length: 101, dtype: int64

# %%
# convert to date format
df['last_pymnt_d'] = '01-' + df['last_pymnt_d']
df['last_pymnt_d'] = pd.to_datetime(df['last_pymnt_d'])

# %%
df['last_pymnt_d'].value_counts()
# Out:
# 2016-05-01    1256
# 2013-03-01    1026
# 2014-12-01     945
# 2013-05-01     907
# 2013-02-01     869
#               ...
# 2008-11-01      10
# 2008-06-01      10
# 2008-03-01       5
# 2008-01-01       4
# 2008-02-01       1
# Name: last_pymnt_d, Length: 101, dtype: int64

# %% [markdown]
# #### column: last_credit_pull_d (Imputation strategy):
# - 1. Convert last_credit_pull_d to date format

# %%
# convert to date format
df['last_credit_pull_d'] = '01-' + df['last_credit_pull_d']
df['last_credit_pull_d'] = pd.to_datetime(df['last_credit_pull_d'])

# %%
df['last_credit_pull_d'].value_counts()
# Out:
# 2016-05-01    10308
# 2016-04-01     2547
# 2016-03-01     1123
# 2013-02-01      843
# 2016-02-01      736
#               ...
# 2008-06-01        1
# 2007-05-01        1
# 2008-07-01        1
# 2008-05-01        1
# 2007-07-01        1
# Name: last_credit_pull_d, Length: 106, dtype: int64

# %% [markdown]
# #### column: term (Imputation strategy):
# - 1. Remove 'months' and convert to int

# %%
df['term'].value_counts()
# Out:
#  36 months    29096
#  60 months    10621
# Name: term, dtype: int64

# %%
df['term'] = df['term'].str.strip('months').astype('int')
df['term'].value_counts()
# Out:
# 36    29096
# 60    10621
# Name: term, dtype: int64

# %% [markdown]
# #### column: term (Imputation strategy):
# - 1. Remove 'months' and convert to int

# %%
df['int_rate'].value_counts()
# Out:
# 10.99%    956
# 13.49%    826
# 11.49%    825
# 7.51%     787
# 7.88%     725
#          ...
# 16.01%      1
# 16.20%      1
# 16.96%      1
# 18.72%      1
# 22.64%      1
# Name: int_rate, Length: 371, dtype: int64

# %%
df['int_rate'] = df['int_rate'].str.strip('%').astype('float')
df['int_rate'].value_counts()
# Out:
# 10.99    956
# 13.49    826
# 11.49    825
# 7.51     787
# 7.88     725
#         ...
# 17.54      1
# 17.44      1
# 20.52      1
# 24.59      1
# 17.34      1
# Name: int_rate, Length: 371, dtype: int64

# %% [markdown]
# #### column: zip_code (Imputation strategy):
# - 1. Remove 'xx' from the end and convert to int

# %%
df['zip_code'] = df['zip_code'].str.strip('xxx').astype('int')
df['zip_code'].value_counts()
# Out:
# 100    597
# 945    545
# 112    516
# 606    503
# 70     473
#       ...
# 669      1
# 369      1
# 385      1
# 353      1
# 465      1
# Name: zip_code, Length: 823, dtype: int64

# %%
df['zip_code'].value_counts()
# Out:
# 100    597
# 945    545
# 112    516
# 606    503
# 70     473
#       ...
# 669      1
# 369      1
# 385      1
# 353      1
# 465      1
# Name: zip_code, Length: 823, dtype: int64

# %% [markdown]
# #### column: pub_rec_bankruptcies (Imputation strategy): [PENDING]
# - 1. Replace rows having null values of pub_rec_bankruptcies with NA ✅
# - 2. check if notna to be used to drop null columns ❌
# -    FINAL Decision is not to do anything as this may skew the data

# %%
df['pub_rec_bankruptcies'].value_counts()
# Out:
# 0.0    37339
# 1.0     1674
# 2.0        7
# Name: pub_rec_bankruptcies, dtype: int64

# %% [markdown]
# #### column: desc (Imputation strategy):
# - 1. Replace rows having null values of desc with NA

# %%
df['desc'] = df['desc'].fillna('NA')

# %%
df['loan_status'].value_counts()
# Out:
# Fully Paid     32950
# Charged Off     5627
# Current         1140
# Name: loan_status, dtype: int64

# %%
df['title'].value_counts() # No Imputation required
# Out:
# Debt Consolidation                      2184
# Debt Consolidation Loan                 1729
# Personal Loan                            659
# Consolidation                            517
# debt consolidation                       505
#                                         ...
# the first step to acheving my dreams       1
# Maxey Debt Consolidation                   1
# Chase pay-down                             1
# do over                                    1
# ankle surgery                              1
# Name: title, Length: 19615, dtype: int64

# %%
# excluding rows with Null values (String Data)
df['emp_title']=df["emp_title"].fillna('NA')
df['emp_title'].value_counts()

# df1 = df [ df["emp_title"].notna() ]
# exluding rows where embarked values is missing
# Out:
# NA                           2459
# US Army                       134
# Bank of America               109
# IBM                            66
# AT&T                           59
#                              ...
# Altura Credit Union             1
# Fieldglass Inc                  1
# Hyundai AMCO America, Inc       1
# marvin & palmer assoc           1
# Paul Tally DDS                  1
# Name: emp_title, Length: 28821, dtype: int64

# %%
df['tax_liens'].value_counts()
# Out:
# 0.0    39678
# Name: tax_liens, dtype: int64

# %%
# df = df [ df['emp_title'] == 'NA' ]

# %%
df1  = 100*df.isnull().mean()
df1[df1>0]
# Out:
# title                         0.027696
# last_pymnt_d                  0.178765
# last_credit_pull_d            0.005036
# collections_12_mths_ex_med    0.140998
# chargeoff_within_12_mths      0.140998
# pub_rec_bankruptcies          1.754916
# tax_liens                     0.098195
# dtype: float64

# %%
df.shape
# Out:
# (39717, 54)

# %% [markdown]
# ##  📋🛑Derived metrics
# - Creating additional attributes (columns) from existing attributes to aid the analysis to determine whether to give loan or not.

# %% [markdown]
# #### 🛑 Create 2 Derived metrics issue_d_year & issue_d_month from issue_d
# - this is done to analyze based on month and year separately

# %%
df['issue_d_month'] = pd.to_datetime('01' + df['issue_d']).dt.month
df['issue_d_year'] = pd.to_datetime('01' + df['issue_d']).dt.year

# %%
df['issue_d_month'].value_counts()
# Out:
# 12    4433
# 11    4167
# 10    3934
# 9     3648
# 8     3518
# 7     3476
# 6     3279
# 5     2999
# 4     2834
# 3     2692
# 1     2379
# 2     2358
# Name: issue_d_month, dtype: int64

# %% [markdown]
# #### 🛑 Create 2 Derived metrics earliest_cr_line_month & earliest_cr_line_year from earliest_cr_line
# - this is done to analyze based on month and year separately

# %%
df['earliest_cr_line_month'] = pd.to_datetime('01' + df['earliest_cr_line']).dt.month
df['earliest_cr_line_year'] = pd.to_datetime('01' + df['earliest_cr_line']).dt.year

# %%
df['earliest_cr_line_month'].value_counts().head()
# Out:
# 10    4076
# 12    4067
# 11    3930
# 9     3593
# 1     3429
# Name: earliest_cr_line_month, dtype: int64

# %%
df['earliest_cr_line_year'].value_counts().head()
# Out:
# 2000    3250
# 1999    2968
# 1998    2851
# 2001    2521
# 1997    2456
# Name: earliest_cr_line_year, dtype: int64

# %%
df['application_type'].value_counts()
# Out:
# INDIVIDUAL    39717
# Name: application_type, dtype: int64

# %% [markdown]
# ### 📋🛑🛑🛑 14.2% customers are not paying their loans i.e., the Bank is Charging off these loans.
# #### To better understand this segment, we will do SEGMENTED DATA ANALYSIS here 🛑🛑🛑📋
# - Create a new attribute 'delinquent' to denote if the  customer has defaulted or not.
# this is based on df['loan_status'] == 'Charged Off']
# - Draw the __correlation__ of the __delinquent column__ of __dfDelinquent dataFRame__ with the other columns.

# %%
df['delinquent'] = df['loan_status']

# %%
df['delinquent'] = df['delinquent'].apply(lambda x: 1 if x == 'Charged Off' else 0)

# %%
df['loan_status'].value_counts()
# Out:
# Fully Paid     32950
# Charged Off     5627
# Current         1140
# Name: loan_status, dtype: int64

# %%
df['delinquent'].value_counts()
# Out:
# 0    34090
# 1     5627
# Name: delinquent, dtype: int64

# %% [markdown]
# ### 🪧FINAL Data shape

# %%
df.shape
# Out:
# (39717, 59)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 39717 entries, 0 to 39716
# Data columns (total 59 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          39717 non-null  int64
#  1   member_id                   39717 non-null  int64
#  2   loan_amnt                   39717 non-null  int64
#  3   funded_amnt                 39717 non-null  int64
#  4   funded_amnt_inv             39717 non-null  float64
#  5   term                        39717 non-null  int32
#  6   int_rate                    39717 non-null  float64
#  7   installment                 39717 non-null  float64
#  8   grade                       39717 non-null  object
#  9   sub_grade                   39717 non-null  object
#  10  emp_title                   39717 non-null  object
#  11  emp_length                  39717 non-null  float64
#  12  home_ownership              39717 non-null  object
# ...

# %% [markdown]
# # 🪧🧱 Section 3: Data analysis 🧱

# %% [markdown]
# ##  📋🛑Univariate analysis
# - Classifying the attributes (columns) into numerical and categorical variables that needs to be analyzed to determine whether to give loan or not.

# %%
# df.info()

# %%
'''
num_cols=['annual_inc', 'collection_recovery_fee', 'collections_12_mths_ex_med','delinq_2yrs','delinq_amnt','dti',
'earliest_cr_line_month','earliest_cr_line_year','emp_length','funded_amnt','unded_amnt_inv','inq_last_6mths',
'installment','int_rate','issue_d_month','issue_d_year','last_pymnt_amnt','loan_amnt','out_prncp','out_prncp_inv',
'recoveries','revol_bal','revol_util','term','total_acc','total_pymnt','total_pymnt_inv','total_rec_int',
'total_rec_late_fee','total_rec_prncp','zip_code']
cat_cols=['addr_state', 'emp_title', 'grade', 'home_ownership', 'loan_status', 'open_acc', 'pub_rec_bankruptcies', 'purpose', 'pymnt_plan', 'sub_grade', 'verification_status']
# extra_cols=["id","member_id","Ticket"]
# len(num_cols)+len(cat_cols)+len(extra_cols)
len(num_cols)+len(cat_cols)
'''
# Out:
# '\nnum_cols=[\'annual_inc\', \'collection_recovery_fee\', \'collections_12_mths_ex_med\',\'delinq_2yrs\',\'delinq_amnt\',\'dti\',\n\'earliest_cr_line_month\',\'earliest_cr_line_year\',\'emp_length\',\'funded_amnt\',\'unded_amnt_inv\',\'inq_last_6mths\',\n\'installment\',\'int_rate\',\'issue_d_month\',\'issue_d_year\',\'last_pymnt_amnt\',\'loan_amnt\',\'out_prncp\',\'out_prncp_inv\',\n\'recoveries\',\'revol_bal\',\'revol_util\',\'term\',\'total_acc\',\'total_pymnt\',\'total_pymnt_inv\',\'total_rec_int\',\n\'total_rec_late_fee\',\'total_rec_prncp\',\'zip_code\']\ncat_cols=[\'addr_state\', \'emp_title\', \'grade\', \'home_ownership\', \'loan_status\', \'open_acc\', \'pub_rec_bankruptcies\', \'purpose\', \'pymnt_plan\', \'sub_grade\', \'verification_status\']\n# extra_cols=["id","member_id","Ticket"]\n# len(num_cols)+len(cat_cols)+len(extra_cols)\nlen(num_cols)+len(cat_cols)\n'

# %% [markdown]
# #### Numerical

# %%
# plot the distribution of all numerical columnsin the dataset post cleansing
numerical_columns = df.select_dtypes(include=['float64', 'int64']).columns
df[numerical_columns].hist(bins=15, figsize=(25, 25), layout=(10, 8))
plt.show()

# %% [markdown]
# #### 🪧🛑Insights from the distribution plot -
# 1. Loan issuance was at the rock bottom during 2007-8 indicating the sub-prime crisis. After 2009, Loan issuance started picking up indicating the resurgance of loan books of banks after the sub-prime crisis was over. Refer column issue_d_year.
# 2. Bulk of the loans are issued in Q4 (last 3 months of the year). Refer column issue_d_month.
# 3. Smaller loan amounts (<10,000 USD) are more likely to be repaid. Refer column loan_amnt.
# 4. Smaller loan instalments (<500 USD) are more likely to be repaid. Refer column installment.
# 5. Loans are more likely to be repaid if the companies/ individuals haven't declared bankruptcy. Refer column pub_rec_bankruptcies.

# %% [markdown]
# #### Categorical

# %%
# Bar plots for categorical columns
categorical_columns = df.select_dtypes(include=['object']).columns
for col in categorical_columns:
    plt.figure(figsize=(10, 5))
    sns.countplot(y=col, data=df)
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-245-69327ae5d5ad> in <module>
#       4     plt.figure(figsize=(10, 5))
#       5     sns.countplot(y=col, data=df)
# ----> 6     plt.show()
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in show(*args, **kwargs)
#     351     """
#     352     _warn_if_gui_out_of_main_thread()
# --> 353     return _backend_mod.show(*args, **kwargs)
#     354
#     355
#
# ~\anaconda3\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      39     try:
#      40         for figure_manager in Gcf.get_all_fig_managers():
# ---> 41             display(
#      42                 figure_manager.canvas.figure,
#      43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# ...

# %% [markdown]
# #### 🪧🛑 Insights from the bar plot of categorical variables -
# 1. A and B grade loans are more likely to be repaid. As grade diminishes, lilelihood of repayment reduces. Refer column grade and sub-grade.
# 2. Those who live on rental are more likely to apply for loan. Refer column home_ownership.
# 3. High proportion of customers' income is not verfied. Refer column verification_status.
# 4. High proportion of customers are repaying their loan. Refer column loan_status.

# %% [markdown]
# ##  📋🛑Bivariate & Multivariate analysis
# - Classifying the attributes (columns) into numerical and categorical variables that needs to be analyzed to determine whether to give loan or not.

# %%
df.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade', 'emp_title',
#        'emp_length', 'home_ownership', 'annual_inc', 'verification_status',
#        'issue_d', 'loan_status', 'pymnt_plan', 'url', 'desc', 'purpose',
#        'title', 'zip_code', 'addr_state', 'dti', 'delinq_2yrs',
#        'earliest_cr_line', 'inq_last_6mths', 'open_acc', 'pub_rec',
#        'revol_bal', 'revol_util', 'total_acc', 'initial_list_status',
#        'out_prncp', 'out_prncp_inv', 'total_pymnt', 'total_pymnt_inv',
#        'total_rec_prncp', 'total_rec_int', 'total_rec_late_fee', 'recoveries',
#        'collection_recovery_fee', 'last_pymnt_d', 'last_pymnt_amnt',
#        'last_credit_pull_d', 'collections_12_mths_ex_med', 'policy_code',
#        'application_type', 'acc_now_delinq', 'chargeoff_within_12_mths',
#        'delinq_amnt', 'pub_rec_bankruptcies', 'tax_liens', 'issue_d_month',
# ...

# %%
df_corr = df[['loan_amnt','int_rate','installment','annual_inc','total_pymnt','total_pymnt_inv','total_rec_prncp',
'total_rec_int','total_rec_late_fee','funded_amnt_inv','collection_recovery_fee','out_prncp','out_prncp_inv' ,'recoveries',
'inq_last_6mths','open_acc','pub_rec','revol_bal','total_acc','last_pymnt_amnt','pub_rec_bankruptcies', 'dti','delinq_2yrs'
,'delinquent']] 
corrmatrix = df_corr.corr() 
f, ax = plt.subplots(figsize=(20, 18))
sns.heatmap(corrmatrix, vmax=.8, square=True, annot=True, cmap='coolwarm');

# %% [markdown]
# ## 🪧📋 Which columns influence Delinquency the most (had been defaulted).
# #### Approach:
# - From above Heatmap and
# - create a correlation matrix of df['delinquent'] with the other numerical columns of the DataFrame

# %%
num_cols = ['loan_amnt','int_rate','installment','annual_inc','total_pymnt','total_pymnt_inv','total_rec_prncp',
'total_rec_int','total_rec_late_fee','funded_amnt_inv','collection_recovery_fee','out_prncp','out_prncp_inv' ,'recoveries',
'inq_last_6mths','open_acc','pub_rec','revol_bal','total_acc','last_pymnt_amnt','pub_rec_bankruptcies', 'dti','delinq_2yrs'
, 'delinquent']
# corrmat = df_corr.corr() 
# sns.heatmap(corrmat, vmax=.8, square=True);

f, ax = plt.subplots(figsize=(20, 15))
sns.heatmap(df[num_cols], vmax=.8, square=True, annot=True, cmap='coolwarm');### 🪧🛑📋 Insights 🛑 Delinquent (had been defaulted). 
- Delinquency has very high co-relation with -
- 1. 
- 2. 
- 3. 
- 4. 
- 5. 
- Hence, we have worked more on this "SEGEMENT of the DATA" with this part of the data. __SEGMENETED DATA ANALYSIS__

# %%
# Select top 5 correlations with df['delinquent']
df_1 = abs(df.corr()['delinquent'])
df_1 [df_1 > 0.21]
# Out:
# total_pymnt        0.238844
# total_pymnt_inv    0.236232
# total_rec_prncp    0.335019
# recoveries         0.340297
# last_pymnt_amnt    0.214949
# delinquent         1.000000
# Name: delinquent, dtype: float64

# %% [markdown]
# ### 🪧🛑📋 Insights:  Delinquency (had been defaulted) criteria
# #### Based on the heatmap and correlation co-efficient of df['delinquency'], we find that Delinquency has very high co-relation with -
# - 1. recoveries (corr = 0.340297) - Higher the post charge-off recovery, higher the chance of deliquency.
# - 2. total_rec_prncp (corr = -0.335019) - lower the loan principal recovery, higher the chances of delinquency
# - 3. total_pymnt (corr = -0.238844) - lower the loan payments received, higher the chances of delinquency
# - 4. total_pymnt_inv (corr = -0.236232) - lower the loan funding amount from investors, higher the chances of delinquency
# - 5. last_pymnt_amnt (corr = -0.214949) - lower the last payment amount received, higher the chances of delinquency

# %% [markdown]
# ### 🪧🛑📋 _loan_status = 'Charge Off'_ means the loan had been Delinquent (had been defaulted).
# - Hence, we have worked more on this "SEGEMENT of the DATA" with this part of the data. __SEGMENETED DATA ANALYSIS__

# %% [markdown]
# #### 🛑 loan_status Insights -
# - 1. 83% of loans are fully paid meaning there's a high proportion of customers repaying their loan, but 14% customers are not repaying their loan.
# - 2. 90% of the charged off loans belongs to the grade B - G.

# %%
loan_status_counts = df['loan_status'].value_counts()
plt.figure(figsize=(6, 6))  # Set the figure size
plt.pie(loan_status_counts, labels=loan_status_counts.index, autopct="%1.1f%%") 
plt.show()

# %%
charged_off_loans = df [ df['loan_status'] == 'Charged Off']['grade'].value_counts()
plt.figure(figsize=(6, 6))  # Set the figure size
plt.pie(charged_off_loans, labels=charged_off_loans.index, autopct="%1.1f%%") 
plt.show()

# %% [markdown]
# ### 📋🛑🛑🛑 14.2% customers are not paying their loans i.e., the Bank is Charging off these loans.
# #### To better understand this segment, we will do SEGMENTED DATA ANALYSIS here 🛑🛑🛑📋
# - __Step 1.__ Create a new attribute 'delinquent' to denote if the  customer has defaulted or not.
# - __Step 2.__ Create a segemented dataFrame called dfDelinquent with df['loan_status'] == 'Charged Off']
# - __Step 3.__  Draw the __correlation__ of the __delinquent column__ of __dfDelinquent dataFRame__ with the other columns.

# %%
## Step 1.
df['delinquent'] = df['loan_status']

# %%
df['delinquent'] = df['delinquent'].apply(lambda x: 1 if x == 'Charged Off' else 0)

# %%
df['loan_status'].value_counts()
# Out:
# Fully Paid     32950
# Charged Off     5627
# Current         1140
# Name: loan_status, dtype: int64

# %%
df['delinquent'].value_counts()
# Out:
# 0    34090
# 1     5627
# Name: delinquent, dtype: int64

# %%
## Step 2.
df [ df['delinquent'] == 1].shape
# Out:
# (5627, 59)

# %%
dfDelinquent = df [ df['delinquent'] == 1]

# %%
dfDelinquent['delinquent'].value_counts()
# Out:
# 1    5627
# Name: delinquent, dtype: int64

# %%
dfDelinquent.shape
# Out:
# (5627, 59)

# %% [markdown]
# #### 🛑 Loan term Insights -
# - 1. 73% of loans are with with tenor = 36 months i.e., short-term loans.
# - 2. 57% of the charged off loans are short-term loans meaning customers are slightly less likely to repay when the loan tenor is smaller.

# %%
loan_term_counts = df['term'].value_counts()
plt.figure(figsize=(6, 6))  # Set the figure size
plt.pie(loan_term_counts.values, labels=loan_term_counts.index, autopct="%1.1f%%")
plt.show()

# %%
charged_off_loans = df [ df['loan_status'] == 'Charged Off']['term'].value_counts()
plt.figure(figsize=(6, 6))  # Set the figure size
plt.pie(charged_off_loans, labels=charged_off_loans.index, autopct="%1.1f%%") 
plt.show()

# %%
# Interest rate box plot
plt.boxplot(df.int_rate)
plt.title("Interest Rate Distribution\n", fontdict={'fontsize': 20, 'fontweight' : 5, 'color' : 'Green'})
plt.ylabel('Interest Rate', fontdict={'fontsize': 12, 'fontweight' : 5, 'color' : 'Brown'})
# Out:
# Text(0, 0.5, 'Interest Rate')

# %%
# Int rate outliars
df[df['int_rate'] >22.5]['int_rate'].value_counts()
# Out:
# 22.74    20
# 23.91    11
# 23.13     9
# 23.22     9
# 23.52     9
# 22.85     8
# 23.59     4
# 24.11     3
# 22.94     2
# 24.59     1
# 24.40     1
# 22.64     1
# Name: int_rate, dtype: int64

# %%
# Interest rate box plot
plt.boxplot(df.loan_amnt)
plt.title("Loan Amount Distribution\n", fontdict={'fontsize': 20, 'fontweight' : 5, 'color' : 'Green'})
plt.ylabel('Loan Amount', fontdict={'fontsize': 12, 'fontweight' : 5, 'color' : 'Brown'})
# Out:
# Text(0, 0.5, 'Loan Amount')

# %%
# Int rate outliars
df[df['loan_amnt'] >32000]['loan_amnt'].value_counts()
# Out:
# 35000    679
# 34000     15
# 33000     12
# 33950      9
# 33600      6
# 34475      5
# 32350      3
# 32400      3
# 32875      2
# 34800      2
# 33425      2
# 33500      2
# 32500      2
# 34675      1
# 32275      1
# 32250      1
# 33250      1
# 34200      1
# 34525      1
# 32525      1
# 32775      1
# Name: loan_amnt, dtype: int64

# %%
# Box plots for numerical vs. categorical columns
for cat_col in categorical_columns:
    for num_col in numerical_columns:
        plt.figure(figsize=(10, 6))
        sns.boxplot(x=df[cat_col], y=df[num_col])
        plt.title(f'{num_col}

# %%
df.int_rate = df.int_rate.astype(float)
out1,bins,out2  = plt.hist(df.int_rate, bins =20)
plt.xticks(bins, rotation=90)
plt.title("Number of loans given at various interest rates\n", fontdict={'fontsize': 20, 'fontweight' : 5, 'color' : 'Green'})
# Labeling Axes
plt.xlabel("Interest Rate", fontdict={'fontsize': 12, 'fontweight' : 5, 'color' : 'Brown'})
plt.ylabel("Number of loans", fontdict={'fontsize': 12, 'fontweight' : 5, 'color' : 'Brown'})
# Out:
# Text(0, 0.5, 'Number of loans')

# %%
df.columns
# Out:
# Index(['id', 'member_id', 'loan_amnt', 'funded_amnt', 'funded_amnt_inv',
#        'term', 'int_rate', 'installment', 'grade', 'sub_grade', 'emp_title',
#        'emp_length', 'home_ownership', 'annual_inc', 'verification_status',
#        'issue_d', 'loan_status', 'pymnt_plan', 'url', 'desc', 'purpose',
#        'title', 'zip_code', 'addr_state', 'dti', 'delinq_2yrs',
#        'earliest_cr_line', 'inq_last_6mths', 'open_acc', 'pub_rec',
#        'revol_bal', 'revol_util', 'total_acc', 'initial_list_status',
#        'out_prncp', 'out_prncp_inv', 'total_pymnt', 'total_pymnt_inv',
#        'total_rec_prncp', 'total_rec_int', 'total_rec_late_fee', 'recoveries',
#        'collection_recovery_fee', 'last_pymnt_d', 'last_pymnt_amnt',
#        'last_credit_pull_d', 'collections_12_mths_ex_med', 'policy_code',
#        'application_type', 'acc_now_delinq', 'chargeoff_within_12_mths',
#        'delinq_amnt', 'pub_rec_bankruptcies', 'tax_liens', 'issue_d_month',
# ...

# %%
'''
df_corr = df[['loan_amnt','int_rate','installment','annual_inc','total_pymnt',
'total_pymnt_inv','total_rec_prncp','total_rec_int','total_rec_late_fee','funded_amnt_inv','collection_recovery_fee','out_prncp','out_prncp_inv' ,'recoveries','inq_last_6mths','open_acc'      
,'pub_rec','revol_bal','total_acc','last_pymnt_amnt','pub_rec_bankruptcies', 'dti','delinq_2yrs', 'delinquent']] 
corrmat = df_corr.corr() 
f, ax = plt.subplots(figsize=(20, 18))
sns.heatmap(corrmat, vmax=.8, square=True, annot=True, cmap='coolwarm');

# %%
import statsmodels.api as sm
sns.lmplot(x='annual_inc', y='loan_amnt', hue='loan_status', data=df)
# sns.lmplot(x='annual_inc', y='loan_amnt', hue='loan_status', data=df, markers=['o', 'x'], fit_reg=False)
plt.show()
